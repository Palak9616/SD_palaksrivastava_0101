# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak9616/SD_palaksrivastava_0101/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,3,9]

# %%
num = []
for i in l:
  num.append(i**2)

# %%
l
# Out:
# [1, 3, 9]

# %%
num = []
for i in l if i%2 ==0
num.append(i)
# Out:
#   File "/tmp/ipykernel_1625/4109472551.py", line 2
#     for i in l if i%2 ==0
#              ^
# SyntaxError: expected 'else' after 'if' expression

# %%
l1 =["palak","coding","srivastava","ai"]

# %%
[i.upper() for i in l1]
# Out:
# ['PALAK', 'CODING', 'SRIVASTAVA', 'AI']

# %%
d ={"key1":1,"key2":2,"key3":3,"key4":4}

# %%
{k:v**2 for k, v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.item =[]
for k,v in d.item():
  d.item[k] = v**2
print(d.item)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1625/3436999696.py in <cell line: 0>()
# ----> 1 d.item =[]
#       2 for k,v in d.item():
#       3   d.item[k] = v**2
#       4 print(d.item)
#
# AttributeError: 'dict' object has no attribute 'item'

# %%
def sum(a,b):

a = 3
b = 4
# Out:
#   File "/tmp/ipykernel_1625/940867798.py", line 3
#     a = 3
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
a+b
# Out:
# 7

# %%
def test1():
  print("palak")

# %%
test1()
# Out:
# palak

# %%
def add_num(a,b):
  s = a+b
  print(s)

a = 3
b = 4
add_num(a,b)
# Out:
# 7

# %%
def test2():
  return "palak"

# %%
test2()
# Out:
# 'palak'

# %%
def test3():
  return "palak",23,45,[5,6,7]

# %%
test3()
# Out:
# ('palak', 23, 45, [5, 6, 7])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'palak'

# %%
type(test3())
# Out:
# tuple

# %%
b
# Out:
# 23

# %%
d
# Out:
# [5, 6, 7]

# %%
def test6(a,b):
 return a+b
test6("palak"," srivastava")
# Out:
# 'palak srivastava'

# %%
def test7(*args):
  return args + 1

# %%
type(test7())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1625/727687955.py in <cell line: 0>()
# ----> 1 type(test7())
#
# /tmp/ipykernel_1625/52900770.py in test7(*args)
#       1 def test7(*args):
# ----> 2   return args + 1
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
def test8(*kwargs):
  return kwargs

# %%
type(test8())
# Out:
# tuple

# %%
def test11(*kwargs):
  return kwargs + [1,2,3,4]

# %%
type(test11())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1625/2134619326.py in <cell line: 0>()
# ----> 1 type(test11())
#
# /tmp/ipykernel_1625/3104172197.py in test11(*kwargs)
#       1 def test11(*kwargs):
# ----> 2   return kwargs + [1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test13(*args,a):
  return args,a

# %%
test13(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1625/2288133206.py in <cell line: 0>()
# ----> 1 test13(1,2,3,4)
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4,a=10)
# Out:
# ((1, 2, 3, 4), 10)

# %%
def tesd14(c,d,a=23,b=1):
  return a,b,c,d

# %%
tesd14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
def test15(**kwargs):
  return kwargs

# %%
type(test15())
# Out:
# dict

# %%
test15(a =[1,2,3,4],b = 'palak',c =23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'palak', 'c': 23.45}

# %%
def add(a,b):
  return a+b
def sub(a,b):
    return a-b
def mut(a,b):
      return a*b
def div(a,b):
      return a/b

# %%
add(10,20)
# Out:
# 30

# %%
mut(20,2)
# Out:
# 40

# %%
sub(20,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_506/3609930798.py in <cell line: 0>()
# ----> 1 sub(20,10)
#
# NameError: name 'sub' is not defined

# %%
cardno = int(input("enter card no"))
print("cardno valid")
print("service")
print("1 withdrow")
print("2 balance")
print("3 deposit")
print("4 exist")
choise = int(input("enter the choise"))
if choise == 1:
    amount = int(input("enter the amount"))
    pin = int(input("enter the pin"))
    print("transition is complete")
elif choise == 3:
              deposit =int(input("enter the deposit"))
              pin = int(input("enter the pin"))
else:
  print("exist")
# Out:
# enter card no548
# cardno valid
# service
# 1 withdrow
# 2 balance
# 3 deposit
# 4 exist
# enter the choise2
# exist

# %%
cardno = int(input("enter card no"))
print("cardno valid")
print("service")
print("1 withdrow")
print("2 balance")
print("3 deposit")
print("4 exist")
choise = int(input("enter the choise"))
if choise == 1:
    amount = int(input("enter the amount"))
    pin = int(input("enter the pin"))
    print("transition is complete")
elif choise == 3:
              deposit =int(input("enter the deposit"))
              pin = int(input("enter the pin"))
else:
  print("exist")
# Out:
# enter card no354
# cardno valid
# service
# 1 withdrow
# 2 balance
# 3 deposit
# 4 exist
# enter the choise3
# enter the deposit67687
# enter the pin87669
