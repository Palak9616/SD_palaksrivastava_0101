# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak9616/SD_palaksrivastava_0101/blob/main/guess_no.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
def guessing_game():
    secret_num = random.randint(1, 100)
    score = 0
    attempts = 0

    print(" Welcome to the Number Guessing Game")
    print("I have chosen a secret number between 1 and 100.")
    print("can you guess it?")
    while True:
      try:
        guess = int(input("enter the guess num"))
        attempts += 1

        if guess == secret_num:
         print("congratulation you guess it.")
         score = 100 - (attempts + 1)
         print("your score",score)
         break

        elif guess > secret_num:
         print(" Too high! Try a lower number.")

        else:
         print("too low! Try a higher number.")

      except ValueError:
       print(" Invalid input. Please enter a whole number.")

if __name__ == "__main__":
                  guessing_game()
# Out:
#  Welcome to the Number Guessing Game
# I have chosen a secret number between 1 and 100.
# can you guess it?
# enter the guess num20
# too low! Try a higher number.
# enter the guess num40
# too low! Try a higher number.
# enter the guess num60
# too low! Try a higher number.
# enter the guess num80
#  Too high! Try a lower number.
# enter the guess num70
# too low! Try a higher number.
# enter the guess num75
#  Too high! Try a lower number.
# enter the guess num72
# too low! Try a higher number.
# enter the guess num74
#  Too high! Try a lower number.
# enter the guess num73
# congratulation you guess it.
# your score 90
